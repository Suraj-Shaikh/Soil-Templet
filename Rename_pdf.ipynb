# %%
import os

folder = r'F:\\Suraj_PC\\Other_work\\NBSS\\NBSS Data\\Map\\PH_2\\Texture\\'
count = 1

# iterate all files from a directory
for file_name in os.listdir(folder):
    # get last 10 characters of the file name including file extanstion(pdf)
    new_name = file_name[-10:] 
    # create new path with the folder and new name
    new_name = os.path.join(folder, new_name)
    # rename the file
    new_name_f = os.rename(os.path.join(folder, file_name), new_name) 
    print(new_name_f)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
